# %%
import pandas as pd
import os

# %% [markdown]
# # Import Datasets
# Dataset
# > Link: https://www.kaggle.com/datasets/arashnic/book-recommendation-dataset

# %%
# file_path = os.path.abspath('./datasets/Books.csv')
books = pd.read_csv('../datasets/Books.csv')

display(books.head())
# Out:
# C:\Users\Syah\AppData\Local\Temp\ipykernel_5812\3755506606.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('../datasets/Books.csv')
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# ...

# %%
display(books.head())
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %% [markdown]
# # Shape of Data

# %%
books.isna().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %% [markdown]
# Membetulkan data NaN yang ada pada kolom Book-Author

# %%
books[books['Book-Author'].isna()]
# Out:
#               ISBN                                         Book-Title  \
# 187689  9627982032  The Credit Suisse Guide to Managing Your Perso...
#
#        Book-Author Year-Of-Publication                       Publisher  \
# 187689         NaN                1995  Edinburgh Financial Publishing
#
#                                               Image-URL-S  \
# 187689  http://images.amazon.com/images/P/9627982032.0...
#
#                                               Image-URL-M  \
# 187689  http://images.amazon.com/images/P/9627982032.0...
#
#                                               Image-URL-L
# 187689  http://images.amazon.com/images/P/9627982032.0...

# %%
books.iloc[187689]['Book-Title']
# Out:
# 'The Credit Suisse Guide to Managing Your Personal Wealth'

# %% [markdown]
# Setelah mencari manual, kami mendapatkan nama author pada buku ini:<br>
# ***Downes, Larissa Anne***

# %%
books.iloc[187689]['Book-Author'] = 'Downes, Larissa Anne'

# %%
books.isna().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %% [markdown]
# Pada Kolom Publisher masih terdapat dua value NaN

# %%
books[books['Publisher'].isna()]
# Out:
#               ISBN       Book-Title      Book-Author Year-Of-Publication  \
# 128890  193169656X      Tyrant Moon  Elaine Corvidae                2002
# 129037  1931696993  Finders Keepers  Linnea Sinclair                2001
#
#        Publisher                                        Image-URL-S  \
# 128890       NaN  http://images.amazon.com/images/P/193169656X.0...
# 129037       NaN  http://images.amazon.com/images/P/1931696993.0...
#
#                                               Image-URL-M  \
# 128890  http://images.amazon.com/images/P/193169656X.0...
# 129037  http://images.amazon.com/images/P/1931696993.0...
#
#                                               Image-URL-L
# 128890  http://images.amazon.com/images/P/193169656X.0...
# 129037  http://images.amazon.com/images/P/1931696993.0...

# %%
books.iloc[128890]['Publisher'] = 'NovelBooks'
books.iloc[129037]['Publisher'] = 'NovelBooks'

# %%
books.isna().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
# initialize data of lists.
data = {'idPerpus': ['173', '213', '913', ],
        'Perpustakaan': ['Perpustakaan Kota Bandung', 'Perpustakaan ITB', 'Perpustakaan UPI'],
        'Alamat':['Jl. Seram No.2, Citarum, Kec. Bandung Wetan, Kota Bandung, Jawa Barat 40115', 'Kawasan ITB Kampus Ganesa, Jl. Ganesa No.10, Lb. Siliwangi, Kecamatan Coblong, Kota Bandung, Jawa Barat 40132', ' Jl. Dr. Setiabudi No.229, Isola, Kec. Sukasari, Kota Bandung, Jawa Barat 40154'],
        'Lon':['107.6137978229117','107.6107340527733','107.59142271780094'],
        'Lat':['-6.908202787856465','-6.888200572853506','-6.860911863002797']
        }
# Create DataFrame
perpus_df = pd.DataFrame(data)
 
# Print the output.
print(perpus_df)
# Out:
#   idPerpus               Perpustakaan  \
# 0      173  Perpustakaan Kota Bandung
# 1      213           Perpustakaan ITB
# 2      913           Perpustakaan UPI
#
#                                               Alamat                 Lon  \
# 0  Jl. Seram No.2, Citarum, Kec. Bandung Wetan, K...   107.6137978229117
# 1  Kawasan ITB Kampus Ganesa, Jl. Ganesa No.10, L...   107.6107340527733
# 2   Jl. Dr. Setiabudi No.229, Isola, Kec. Sukasar...  107.59142271780094
#
#                   Lat
# 0  -6.908202787856465
# 1  -6.888200572853506
# 2  -6.860911863002797

# %%
perpus_df
# Out:
#   idPerpus               Perpustakaan  \
# 0      173  Perpustakaan Kota Bandung
# 1      213           Perpustakaan ITB
# 2      913           Perpustakaan UPI
#
#                                               Alamat                 Lon  \
# 0  Jl. Seram No.2, Citarum, Kec. Bandung Wetan, K...   107.6137978229117
# 1  Kawasan ITB Kampus Ganesa, Jl. Ganesa No.10, L...   107.6107340527733
# 2   Jl. Dr. Setiabudi No.229, Isola, Kec. Sukasar...  107.59142271780094
#
#                   Lat
# 0  -6.908202787856465
# 1  -6.888200572853506
# 2  -6.860911863002797

# %%
import random
id_perpus_values = (list(perpus_df['idPerpus']) * (len(books) // len(perpus_df) + 1))[:len(books)]
random.shuffle(id_perpus_values)

books['idPerpus'] = id_perpus_values

# %%
display(books)
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
columns_to_drop = ['Image-URL-S', 'Image-URL-L', 'Image-URL-M']
books = books.drop(columns=columns_to_drop, axis=1)

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#   idPerpus
# 0      213
# 1      913
# 2      913
# 3      213
# 4      213

# %%
books.to_csv('../datasets/CleanDataBook.csv',index=False)
perpus_df.to_csv('../datasets/Perpustakaan.csv',index=False)
